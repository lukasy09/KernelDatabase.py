# %%
import numpy as np
import librosa
import math
import re
import os
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical 
from sklearn.model_selection import train_test_split
# Out:
# D:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
class AudioDataGenerator:
    
    dir_train = "./digit_dataset/train"
    num_classes = 10 #  Digits [0-9]
    
    def __init__(self):
        self.hop_length = 512
        self.timeseries_length_list = []
        
    def preprocessSingleFile(self, file):
        timeseries_length = 6
        hop_length = 512
        data = np.zeros((1, timeseries_length, 33), dtype=np.float64)
        
        y, sr = librosa.load(file)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length= 512, n_mfcc= 13)
        spectral_center = librosa.feature.spectral_centroid(y=y, sr=sr, hop_length= hop_length)
        chroma = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=hop_length)
        spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=hop_length)


        data[0, :, 0:13] = mfcc.T[0:timeseries_length, :]
        data[0, :, 13:14] = spectral_center.T[0:timeseries_length, :]
        data[0, :, 14:26] = chroma.T[0:timeseries_length, :]
        data[0, :, 26:33] = spectral_contrast.T[0:timeseries_length, :]
        
        return data
        
        
        
        
    def oneHotEncode(self,num_classes):
        encoder = LabelEncoder()
        
        self.train_Y = encoder.fit_transform(self.train_Y)
        self.train_Y = to_categorical(self.train_Y, num_classes)
  
    def path_to_audiofiles(self, dir_folder):
        list_of_audio = []
        for file in os.listdir(dir_folder):
            if file.endswith(".au") or file.endswith(".wav") or file.endswith(".wma"):
                directory = "%s/%s" % (dir_folder, file)
                list_of_audio.append(directory)
        return list_of_audio    
     
        
    def completePreprocessAudio(self):
        trainfiles_list = self.path_to_audiofiles(self.dir_train)
        
        #Whole dataset.
        self.train_X, self.train_Y=self.extractAudioFeatures(trainfiles_list)
    
        self.oneHotEncode(self.num_classes)
        
    
    def extractAudioFeatures(self, list_of_audiofiles):
        timeseries_length = 6
        hop_length = 512
        data = np.zeros((len(list_of_audiofiles), timeseries_length, 33), dtype=np.float64)
        target = []

        for i, file in enumerate(list_of_audiofiles):

            y, sr = librosa.load(file)
            mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length= 512, n_mfcc= 13)
            spectral_center = librosa.feature.spectral_centroid(y=y, sr=sr, hop_length= hop_length)
            chroma = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=hop_length)
            spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=hop_length)

            genre  = file[22]
            target.append(genre)

            data[i, :, 0:13] = mfcc.T[0:timeseries_length, :]
            data[i, :, 13:14] = spectral_center.T[0:timeseries_length, :]
            data[i, :, 14:26] = chroma.T[0:timeseries_length, :]
            data[i, :, 26:33] = spectral_contrast.T[0:timeseries_length, :]
            print("File:",file," ",i + 1," of ", len(list_of_audiofiles))
            
        print("All dataset features have been extracted.")
        return data, np.expand_dims(np.asarray(target), axis=1)

# %%
datagen = AudioDataGenerator()
datagen.completePreprocessAudio()
# Out:
# File: ./digit_dataset/train/0_jackson_0.wav   1  of  1500
# File: ./digit_dataset/train/0_jackson_1.wav   2  of  1500
# File: ./digit_dataset/train/0_jackson_10.wav   3  of  1500
# File: ./digit_dataset/train/0_jackson_11.wav   4  of  1500
# File: ./digit_dataset/train/0_jackson_12.wav   5  of  1500
# File: ./digit_dataset/train/0_jackson_13.wav   6  of  1500
# File: ./digit_dataset/train/0_jackson_14.wav   7  of  1500
# File: ./digit_dataset/train/0_jackson_15.wav   8  of  1500
# File: ./digit_dataset/train/0_jackson_16.wav   9  of  1500
# File: ./digit_dataset/train/0_jackson_17.wav   10  of  1500
# File: ./digit_dataset/train/0_jackson_18.wav   11  of  1500
# File: ./digit_dataset/train/0_jackson_19.wav   12  of  1500
# File: ./digit_dataset/train/0_jackson_2.wav   13  of  1500
# File: ./digit_dataset/train/0_jackson_20.wav   14  of  1500
# File: ./digit_dataset/train/0_jackson_21.wav   15  of  1500
# File: ./digit_dataset/train/0_jackson_22.wav   16  of  1500
# File: ./digit_dataset/train/0_jackson_23.wav   17  of  1500
# File: ./digit_dataset/train/0_jackson_24.wav   18  of  1500
# File: ./digit_dataset/train/0_jackson_25.wav   19  of  1500
# File: ./digit_dataset/train/0_jackson_26.wav   20  of  1500
# File: ./digit_dataset/train/0_jackson_27.wav   21  of  1500
# File: ./digit_dataset/train/0_jackson_28.wav   22  of  1500
# File: ./digit_dataset/train/0_jackson_29.wav   23  of  1500
# File: ./digit_dataset/train/0_jackson_3.wav   24  of  1500
# File: ./digit_dataset/train/0_jackson_30.wav   25  of  1500
# File: ./digit_dataset/train/0_jackson_31.wav   26  of  1500
# File: ./digit_dataset/train/0_jackson_32.wav   27  of  1500
# File: ./digit_dataset/train/0_jackson_33.wav   28  of  1500
# File: ./digit_dataset/train/0_jackson_34.wav   29  of  1500
# File: ./digit_dataset/train/0_jackson_35.wav   30  of  1500
# File: ./digit_dataset/train/0_jackson_36.wav   31  of  1500
# File: ./digit_dataset/train/0_jackson_37.wav   32  of  1500
# File: ./digit_dataset/train/0_jackson_38.wav   33  of  1500
# File: ./digit_dataset/train/0_jackson_39.wav   34  of  1500
# File: ./digit_dataset/train/0_jackson_4.wav   35  of  1500
# File: ./digit_dataset/train/0_jackson_40.wav   36  of  1500
# File: ./digit_dataset/train/0_jackson_41.wav   37  of  1500
# File: ./digit_dataset/train/0_jackson_42.wav   38  of  1500
# File: ./digit_dataset/train/0_jackson_43.wav   39  of  1500
# File: ./digit_dataset/train/0_jackson_44.wav   40  of  1500
# File: ./digit_dataset/train/0_jackson_45.wav   41  of  1500
# File: ./digit_dataset/train/0_jackson_46.wav   42  of  1500
# File: ./digit_dataset/train/0_jackson_47.wav   43  of  1500
# File: ./digit_dataset/train/0_jackson_48.wav   44  of  1500
# File: ./digit_dataset/train/0_jackson_49.wav   45  of  1500
# File: ./digit_dataset/train/0_jackson_5.wav   46  of  1500
# File: ./digit_dataset/train/0_jackson_6.wav   47  of  1500
# File: ./digit_dataset/train/0_jackson_7.wav   48  of  1500
# File: ./digit_dataset/train/0_jackson_8.wav   49  of  1500
# File: ./digit_dataset/train/0_jackson_9.wav   50  of  1500
# File: ./digit_dataset/train/0_nicolas_0.wav   51  of  1500
# File: ./digit_dataset/train/0_nicolas_1.wav   52  of  1500
# File: ./digit_dataset/train/0_nicolas_10.wav   53  of  1500
# File: ./digit_dataset/train/0_nicolas_11.wav   54  of  1500
# File: ./digit_dataset/train/0_nicolas_12.wav   55  of  1500
# File: ./digit_dataset/train/0_nicolas_13.wav   56  of  1500
# File: ./digit_dataset/train/0_nicolas_14.wav   57  of  1500
# File: ./digit_dataset/train/0_nicolas_15.wav   58  of  1500
# File: ./digit_dataset/train/0_nicolas_16.wav   59  of  1500
# File: ./digit_dataset/train/0_nicolas_17.wav   60  of  1500
# File: ./digit_dataset/train/0_nicolas_18.wav   61  of  1500
# File: ./digit_dataset/train/0_nicolas_19.wav   62  of  1500
# File: ./digit_dataset/train/0_nicolas_2.wav   63  of  1500
# File: ./digit_dataset/train/0_nicolas_20.wav   64  of  1500
# File: ./digit_dataset/train/0_nicolas_21.wav   65  of  1500
# File: ./digit_dataset/train/0_nicolas_22.wav   66  of  1500
# File: ./digit_dataset/train/0_nicolas_23.wav   67  of  1500
# File: ./digit_dataset/train/0_nicolas_24.wav   68  of  1500
# File: ./digit_dataset/train/0_nicolas_25.wav   69  of  1500
# File: ./digit_dataset/train/0_nicolas_26.wav   70  of  1500
# File: ./digit_dataset/train/0_nicolas_27.wav   71  of  1500
# File: ./digit_dataset/train/0_nicolas_28.wav   72  of  1500
# File: ./digit_dataset/train/0_nicolas_29.wav   73  of  1500
# File: ./digit_dataset/train/0_nicolas_3.wav   74  of  1500
# File: ./digit_dataset/train/0_nicolas_30.wav   75  of  1500
# File: ./digit_dataset/train/0_nicolas_31.wav   76  of  1500
# File: ./digit_dataset/train/0_nicolas_32.wav   77  of  1500
# File: ./digit_dataset/train/0_nicolas_33.wav   78  of  1500
# File: ./digit_dataset/train/0_nicolas_34.wav   79  of  1500
# File: ./digit_dataset/train/0_nicolas_35.wav   80  of  1500
# File: ./digit_dataset/train/0_nicolas_36.wav   81  of  1500
# File: ./digit_dataset/train/0_nicolas_37.wav   82  of  1500
# File: ./digit_dataset/train/0_nicolas_38.wav   83  of  1500
# File: ./digit_dataset/train/0_nicolas_39.wav   84  of  1500
# File: ./digit_dataset/train/0_nicolas_4.wav   85  of  1500
# File: ./digit_dataset/train/0_nicolas_40.wav   86  of  1500
# File: ./digit_dataset/train/0_nicolas_41.wav   87  of  1500
# File: ./digit_dataset/train/0_nicolas_42.wav   88  of  1500
# File: ./digit_dataset/train/0_nicolas_43.wav   89  of  1500
# File: ./digit_dataset/train/0_nicolas_44.wav   90  of  1500
# File: ./digit_dataset/train/0_nicolas_45.wav   91  of  1500
# File: ./digit_dataset/train/0_nicolas_46.wav   92  of  1500
# File: ./digit_dataset/train/0_nicolas_47.wav   93  of  1500
# File: ./digit_dataset/train/0_nicolas_48.wav   94  of  1500
# File: ./digit_dataset/train/0_nicolas_49.wav   95  of  1500
# File: ./digit_dataset/train/0_nicolas_5.wav   96  of  1500
# File: ./digit_dataset/train/0_nicolas_6.wav   97  of  1500
# File: ./digit_dataset/train/0_nicolas_7.wav   98  of  1500
# File: ./digit_dataset/train/0_nicolas_8.wav   99  of  1500
# File: ./digit_dataset/train/0_nicolas_9.wav   100  of  1500
# File: ./digit_dataset/train/0_theo_0.wav   101  of  1500
# File: ./digit_dataset/train/0_theo_1.wav   102  of  1500
# File: ./digit_dataset/train/0_theo_10.wav   103  of  1500
# File: ./digit_dataset/train/0_theo_11.wav   104  of  1500
# File: ./digit_dataset/train/0_theo_12.wav   105  of  1500
# File: ./digit_dataset/train/0_theo_13.wav   106  of  1500
# File: ./digit_dataset/train/0_theo_14.wav   107  of  1500
# File: ./digit_dataset/train/0_theo_15.wav   108  of  1500
# File: ./digit_dataset/train/0_theo_16.wav   109  of  1500
# File: ./digit_dataset/train/0_theo_17.wav   110  of  1500
# File: ./digit_dataset/train/0_theo_18.wav   111  of  1500
# File: ./digit_dataset/train/0_theo_19.wav   112  of  1500
# File: ./digit_dataset/train/0_theo_2.wav   113  of  1500
# File: ./digit_dataset/train/0_theo_20.wav   114  of  1500
# File: ./digit_dataset/train/0_theo_21.wav   115  of  1500
# File: ./digit_dataset/train/0_theo_22.wav   116  of  1500
# File: ./digit_dataset/train/0_theo_23.wav   117  of  1500
# File: ./digit_dataset/train/0_theo_24.wav   118  of  1500
# File: ./digit_dataset/train/0_theo_25.wav   119  of  1500
# File: ./digit_dataset/train/0_theo_26.wav   120  of  1500
# File: ./digit_dataset/train/0_theo_27.wav   121  of  1500
# File: ./digit_dataset/train/0_theo_28.wav   122  of  1500
# File: ./digit_dataset/train/0_theo_29.wav   123  of  1500
# File: ./digit_dataset/train/0_theo_3.wav   124  of  1500
# File: ./digit_dataset/train/0_theo_30.wav   125  of  1500
# File: ./digit_dataset/train/0_theo_31.wav   126  of  1500
# File: ./digit_dataset/train/0_theo_32.wav   127  of  1500
# File: ./digit_dataset/train/0_theo_33.wav   128  of  1500
# File: ./digit_dataset/train/0_theo_34.wav   129  of  1500
# File: ./digit_dataset/train/0_theo_35.wav   130  of  1500
# File: ./digit_dataset/train/0_theo_36.wav   131  of  1500
# File: ./digit_dataset/train/0_theo_37.wav   132  of  1500
# File: ./digit_dataset/train/0_theo_38.wav   133  of  1500
# File: ./digit_dataset/train/0_theo_39.wav   134  of  1500
# File: ./digit_dataset/train/0_theo_4.wav   135  of  1500
# File: ./digit_dataset/train/0_theo_40.wav   136  of  1500
# File: ./digit_dataset/train/0_theo_41.wav   137  of  1500
# File: ./digit_dataset/train/0_theo_42.wav   138  of  1500
# File: ./digit_dataset/train/0_theo_43.wav   139  of  1500
# File: ./digit_dataset/train/0_theo_44.wav   140  of  1500
# File: ./digit_dataset/train/0_theo_45.wav   141  of  1500
# File: ./digit_dataset/train/0_theo_46.wav   142  of  1500
# File: ./digit_dataset/train/0_theo_47.wav   143  of  1500
# File: ./digit_dataset/train/0_theo_48.wav   144  of  1500
# File: ./digit_dataset/train/0_theo_49.wav   145  of  1500
# File: ./digit_dataset/train/0_theo_5.wav   146  of  1500
# File: ./digit_dataset/train/0_theo_6.wav   147  of  1500
# File: ./digit_dataset/train/0_theo_7.wav   148  of  1500
# File: ./digit_dataset/train/0_theo_8.wav   149  of  1500
# File: ./digit_dataset/train/0_theo_9.wav   150  of  1500
# File: ./digit_dataset/train/1_jackson_0.wav   151  of  1500
# File: ./digit_dataset/train/1_jackson_1.wav   152  of  1500
# File: ./digit_dataset/train/1_jackson_10.wav   153  of  1500
# File: ./digit_dataset/train/1_jackson_11.wav   154  of  1500
# File: ./digit_dataset/train/1_jackson_12.wav   155  of  1500
# File: ./digit_dataset/train/1_jackson_13.wav   156  of  1500
# File: ./digit_dataset/train/1_jackson_14.wav   157  of  1500
# File: ./digit_dataset/train/1_jackson_15.wav   158  of  1500
# File: ./digit_dataset/train/1_jackson_16.wav   159  of  1500
# File: ./digit_dataset/train/1_jackson_17.wav   160  of  1500
# File: ./digit_dataset/train/1_jackson_18.wav   161  of  1500
# File: ./digit_dataset/train/1_jackson_19.wav   162  of  1500
# File: ./digit_dataset/train/1_jackson_2.wav   163  of  1500
# File: ./digit_dataset/train/1_jackson_20.wav   164  of  1500
# File: ./digit_dataset/train/1_jackson_21.wav   165  of  1500
# File: ./digit_dataset/train/1_jackson_22.wav   166  of  1500
# File: ./digit_dataset/train/1_jackson_23.wav   167  of  1500
# File: ./digit_dataset/train/1_jackson_24.wav   168  of  1500
# File: ./digit_dataset/train/1_jackson_25.wav   169  of  1500
# File: ./digit_dataset/train/1_jackson_26.wav   170  of  1500
# File: ./digit_dataset/train/1_jackson_27.wav   171  of  1500
# File: ./digit_dataset/train/1_jackson_28.wav   172  of  1500
# File: ./digit_dataset/train/1_jackson_29.wav   173  of  1500
# File: ./digit_dataset/train/1_jackson_3.wav   174  of  1500
# File: ./digit_dataset/train/1_jackson_30.wav   175  of  1500
# File: ./digit_dataset/train/1_jackson_31.wav   176  of  1500
# File: ./digit_dataset/train/1_jackson_32.wav   177  of  1500
# File: ./digit_dataset/train/1_jackson_33.wav   178  of  1500
# File: ./digit_dataset/train/1_jackson_34.wav   179  of  1500
# File: ./digit_dataset/train/1_jackson_35.wav   180  of  1500
# File: ./digit_dataset/train/1_jackson_36.wav   181  of  1500
# File: ./digit_dataset/train/1_jackson_37.wav   182  of  1500
# File: ./digit_dataset/train/1_jackson_38.wav   183  of  1500
# File: ./digit_dataset/train/1_jackson_39.wav   184  of  1500
# File: ./digit_dataset/train/1_jackson_4.wav   185  of  1500
# File: ./digit_dataset/train/1_jackson_40.wav   186  of  1500
# File: ./digit_dataset/train/1_jackson_41.wav   187  of  1500
# File: ./digit_dataset/train/1_jackson_42.wav   188  of  1500
# File: ./digit_dataset/train/1_jackson_43.wav   189  of  1500
# File: ./digit_dataset/train/1_jackson_44.wav   190  of  1500
# File: ./digit_dataset/train/1_jackson_45.wav   191  of  1500
# File: ./digit_dataset/train/1_jackson_46.wav   192  of  1500
# File: ./digit_dataset/train/1_jackson_47.wav   193  of  1500
# File: ./digit_dataset/train/1_jackson_48.wav   194  of  1500
# File: ./digit_dataset/train/1_jackson_49.wav   195  of  1500
# File: ./digit_dataset/train/1_jackson_5.wav   196  of  1500
# File: ./digit_dataset/train/1_jackson_6.wav   197  of  1500
# File: ./digit_dataset/train/1_jackson_7.wav   198  of  1500
# File: ./digit_dataset/train/1_jackson_8.wav   199  of  1500
# File: ./digit_dataset/train/1_jackson_9.wav   200  of  1500
# File: ./digit_dataset/train/1_nicolas_0.wav   201  of  1500
# File: ./digit_dataset/train/1_nicolas_1.wav   202  of  1500
# File: ./digit_dataset/train/1_nicolas_10.wav   203  of  1500
# File: ./digit_dataset/train/1_nicolas_11.wav   204  of  1500
# File: ./digit_dataset/train/1_nicolas_12.wav   205  of  1500
# File: ./digit_dataset/train/1_nicolas_13.wav   206  of  1500
# File: ./digit_dataset/train/1_nicolas_14.wav   207  of  1500
# File: ./digit_dataset/train/1_nicolas_15.wav   208  of  1500
# File: ./digit_dataset/train/1_nicolas_16.wav   209  of  1500
# File: ./digit_dataset/train/1_nicolas_17.wav   210  of  1500
# File: ./digit_dataset/train/1_nicolas_18.wav   211  of  1500
# File: ./digit_dataset/train/1_nicolas_19.wav   212  of  1500
# File: ./digit_dataset/train/1_nicolas_2.wav   213  of  1500
# File: ./digit_dataset/train/1_nicolas_20.wav   214  of  1500
# File: ./digit_dataset/train/1_nicolas_21.wav   215  of  1500
# File: ./digit_dataset/train/1_nicolas_22.wav   216  of  1500
# File: ./digit_dataset/train/1_nicolas_23.wav   217  of  1500
# File: ./digit_dataset/train/1_nicolas_24.wav   218  of  1500
# File: ./digit_dataset/train/1_nicolas_25.wav   219  of  1500
# File: ./digit_dataset/train/1_nicolas_26.wav   220  of  1500
# File: ./digit_dataset/train/1_nicolas_27.wav   221  of  1500
# File: ./digit_dataset/train/1_nicolas_28.wav   222  of  1500
# File: ./digit_dataset/train/1_nicolas_29.wav   223  of  1500
# File: ./digit_dataset/train/1_nicolas_3.wav   224  of  1500
# File: ./digit_dataset/train/1_nicolas_30.wav   225  of  1500
# File: ./digit_dataset/train/1_nicolas_31.wav   226  of  1500
# File: ./digit_dataset/train/1_nicolas_32.wav   227  of  1500
# File: ./digit_dataset/train/1_nicolas_33.wav   228  of  1500
# File: ./digit_dataset/train/1_nicolas_34.wav   229  of  1500
# File: ./digit_dataset/train/1_nicolas_35.wav   230  of  1500
# File: ./digit_dataset/train/1_nicolas_36.wav   231  of  1500
# File: ./digit_dataset/train/1_nicolas_37.wav   232  of  1500
# File: ./digit_dataset/train/1_nicolas_38.wav   233  of  1500
# File: ./digit_dataset/train/1_nicolas_39.wav   234  of  1500
# File: ./digit_dataset/train/1_nicolas_4.wav   235  of  1500
# File: ./digit_dataset/train/1_nicolas_40.wav   236  of  1500
# File: ./digit_dataset/train/1_nicolas_41.wav   237  of  1500
# File: ./digit_dataset/train/1_nicolas_42.wav   238  of  1500
# File: ./digit_dataset/train/1_nicolas_43.wav   239  of  1500
# File: ./digit_dataset/train/1_nicolas_44.wav   240  of  1500
# File: ./digit_dataset/train/1_nicolas_45.wav   241  of  1500
# File: ./digit_dataset/train/1_nicolas_46.wav   242  of  1500
# File: ./digit_dataset/train/1_nicolas_47.wav   243  of  1500
# File: ./digit_dataset/train/1_nicolas_48.wav   244  of  1500
# File: ./digit_dataset/train/1_nicolas_49.wav   245  of  1500
# File: ./digit_dataset/train/1_nicolas_5.wav   246  of  1500
# File: ./digit_dataset/train/1_nicolas_6.wav   247  of  1500
# File: ./digit_dataset/train/1_nicolas_7.wav   248  of  1500
# File: ./digit_dataset/train/1_nicolas_8.wav   249  of  1500
# File: ./digit_dataset/train/1_nicolas_9.wav   250  of  1500
# File: ./digit_dataset/train/1_theo_0.wav   251  of  1500
# File: ./digit_dataset/train/1_theo_1.wav   252  of  1500
# File: ./digit_dataset/train/1_theo_10.wav   253  of  1500
# File: ./digit_dataset/train/1_theo_11.wav   254  of  1500
# File: ./digit_dataset/train/1_theo_12.wav   255  of  1500
# File: ./digit_dataset/train/1_theo_13.wav   256  of  1500
# File: ./digit_dataset/train/1_theo_14.wav   257  of  1500
# File: ./digit_dataset/train/1_theo_15.wav   258  of  1500
# File: ./digit_dataset/train/1_theo_16.wav   259  of  1500
# File: ./digit_dataset/train/1_theo_17.wav   260  of  1500
# File: ./digit_dataset/train/1_theo_18.wav   261  of  1500
# File: ./digit_dataset/train/1_theo_19.wav   262  of  1500
# File: ./digit_dataset/train/1_theo_2.wav   263  of  1500
# File: ./digit_dataset/train/1_theo_20.wav   264  of  1500
# File: ./digit_dataset/train/1_theo_21.wav   265  of  1500
# File: ./digit_dataset/train/1_theo_22.wav   266  of  1500
# File: ./digit_dataset/train/1_theo_23.wav   267  of  1500
# File: ./digit_dataset/train/1_theo_24.wav   268  of  1500
# File: ./digit_dataset/train/1_theo_25.wav   269  of  1500
# File: ./digit_dataset/train/1_theo_26.wav   270  of  1500
# File: ./digit_dataset/train/1_theo_27.wav   271  of  1500
# File: ./digit_dataset/train/1_theo_28.wav   272  of  1500
# File: ./digit_dataset/train/1_theo_29.wav   273  of  1500
# File: ./digit_dataset/train/1_theo_3.wav   274  of  1500
# File: ./digit_dataset/train/1_theo_30.wav   275  of  1500
# File: ./digit_dataset/train/1_theo_31.wav   276  of  1500
# File: ./digit_dataset/train/1_theo_32.wav   277  of  1500
# File: ./digit_dataset/train/1_theo_33.wav   278  of  1500
# File: ./digit_dataset/train/1_theo_34.wav   279  of  1500
# File: ./digit_dataset/train/1_theo_35.wav   280  of  1500
# File: ./digit_dataset/train/1_theo_36.wav   281  of  1500
# File: ./digit_dataset/train/1_theo_37.wav   282  of  1500
# File: ./digit_dataset/train/1_theo_38.wav   283  of  1500
# File: ./digit_dataset/train/1_theo_39.wav   284  of  1500
# File: ./digit_dataset/train/1_theo_4.wav   285  of  1500
# File: ./digit_dataset/train/1_theo_40.wav   286  of  1500
# File: ./digit_dataset/train/1_theo_41.wav   287  of  1500
# File: ./digit_dataset/train/1_theo_42.wav   288  of  1500
# File: ./digit_dataset/train/1_theo_43.wav   289  of  1500
# File: ./digit_dataset/train/1_theo_44.wav   290  of  1500
# File: ./digit_dataset/train/1_theo_45.wav   291  of  1500
# File: ./digit_dataset/train/1_theo_46.wav   292  of  1500
# File: ./digit_dataset/train/1_theo_47.wav   293  of  1500
# File: ./digit_dataset/train/1_theo_48.wav   294  of  1500
# File: ./digit_dataset/train/1_theo_49.wav   295  of  1500
# File: ./digit_dataset/train/1_theo_5.wav   296  of  1500
# File: ./digit_dataset/train/1_theo_6.wav   297  of  1500
# File: ./digit_dataset/train/1_theo_7.wav   298  of  1500
# File: ./digit_dataset/train/1_theo_8.wav   299  of  1500
# File: ./digit_dataset/train/1_theo_9.wav   300  of  1500
# File: ./digit_dataset/train/2_jackson_0.wav   301  of  1500
# File: ./digit_dataset/train/2_jackson_1.wav   302  of  1500
# File: ./digit_dataset/train/2_jackson_10.wav   303  of  1500
# File: ./digit_dataset/train/2_jackson_11.wav   304  of  1500
# File: ./digit_dataset/train/2_jackson_12.wav   305  of  1500
# File: ./digit_dataset/train/2_jackson_13.wav   306  of  1500
# File: ./digit_dataset/train/2_jackson_14.wav   307  of  1500
# File: ./digit_dataset/train/2_jackson_15.wav   308  of  1500
# File: ./digit_dataset/train/2_jackson_16.wav   309  of  1500
# File: ./digit_dataset/train/2_jackson_17.wav   310  of  1500
# File: ./digit_dataset/train/2_jackson_18.wav   311  of  1500
# File: ./digit_dataset/train/2_jackson_19.wav   312  of  1500
# File: ./digit_dataset/train/2_jackson_2.wav   313  of  1500
# File: ./digit_dataset/train/2_jackson_20.wav   314  of  1500
# File: ./digit_dataset/train/2_jackson_21.wav   315  of  1500
# File: ./digit_dataset/train/2_jackson_22.wav   316  of  1500
# File: ./digit_dataset/train/2_jackson_23.wav   317  of  1500
# File: ./digit_dataset/train/2_jackson_24.wav   318  of  1500
# File: ./digit_dataset/train/2_jackson_25.wav   319  of  1500
# File: ./digit_dataset/train/2_jackson_26.wav   320  of  1500
# File: ./digit_dataset/train/2_jackson_27.wav   321  of  1500
# File: ./digit_dataset/train/2_jackson_28.wav   322  of  1500
# File: ./digit_dataset/train/2_jackson_29.wav   323  of  1500
# File: ./digit_dataset/train/2_jackson_3.wav   324  of  1500
# File: ./digit_dataset/train/2_jackson_30.wav   325  of  1500
# File: ./digit_dataset/train/2_jackson_31.wav   326  of  1500
# File: ./digit_dataset/train/2_jackson_32.wav   327  of  1500
# File: ./digit_dataset/train/2_jackson_33.wav   328  of  1500
# File: ./digit_dataset/train/2_jackson_34.wav   329  of  1500
# File: ./digit_dataset/train/2_jackson_35.wav   330  of  1500
# File: ./digit_dataset/train/2_jackson_36.wav   331  of  1500
# File: ./digit_dataset/train/2_jackson_37.wav   332  of  1500
# File: ./digit_dataset/train/2_jackson_38.wav   333  of  1500
# File: ./digit_dataset/train/2_jackson_39.wav   334  of  1500
# File: ./digit_dataset/train/2_jackson_4.wav   335  of  1500
# File: ./digit_dataset/train/2_jackson_40.wav   336  of  1500
# File: ./digit_dataset/train/2_jackson_41.wav   337  of  1500
# File: ./digit_dataset/train/2_jackson_42.wav   338  of  1500
# File: ./digit_dataset/train/2_jackson_43.wav   339  of  1500
# File: ./digit_dataset/train/2_jackson_44.wav   340  of  1500
# File: ./digit_dataset/train/2_jackson_45.wav   341  of  1500
# File: ./digit_dataset/train/2_jackson_46.wav   342  of  1500
# File: ./digit_dataset/train/2_jackson_47.wav   343  of  1500
# File: ./digit_dataset/train/2_jackson_48.wav   344  of  1500
# File: ./digit_dataset/train/2_jackson_49.wav   345  of  1500
# File: ./digit_dataset/train/2_jackson_5.wav   346  of  1500
# File: ./digit_dataset/train/2_jackson_6.wav   347  of  1500
# File: ./digit_dataset/train/2_jackson_7.wav   348  of  1500
# File: ./digit_dataset/train/2_jackson_8.wav   349  of  1500
# File: ./digit_dataset/train/2_jackson_9.wav   350  of  1500
# File: ./digit_dataset/train/2_nicolas_0.wav   351  of  1500
# File: ./digit_dataset/train/2_nicolas_1.wav   352  of  1500
# File: ./digit_dataset/train/2_nicolas_10.wav   353  of  1500
# File: ./digit_dataset/train/2_nicolas_11.wav   354  of  1500
# File: ./digit_dataset/train/2_nicolas_12.wav   355  of  1500
# File: ./digit_dataset/train/2_nicolas_13.wav   356  of  1500
# File: ./digit_dataset/train/2_nicolas_14.wav   357  of  1500
# File: ./digit_dataset/train/2_nicolas_15.wav   358  of  1500
# File: ./digit_dataset/train/2_nicolas_16.wav   359  of  1500
# File: ./digit_dataset/train/2_nicolas_17.wav   360  of  1500
# File: ./digit_dataset/train/2_nicolas_18.wav   361  of  1500
# File: ./digit_dataset/train/2_nicolas_19.wav   362  of  1500
# File: ./digit_dataset/train/2_nicolas_2.wav   363  of  1500
# File: ./digit_dataset/train/2_nicolas_20.wav   364  of  1500
# File: ./digit_dataset/train/2_nicolas_21.wav   365  of  1500
# File: ./digit_dataset/train/2_nicolas_22.wav   366  of  1500
# File: ./digit_dataset/train/2_nicolas_23.wav   367  of  1500
# File: ./digit_dataset/train/2_nicolas_24.wav   368  of  1500
# File: ./digit_dataset/train/2_nicolas_25.wav   369  of  1500
# File: ./digit_dataset/train/2_nicolas_26.wav   370  of  1500
# File: ./digit_dataset/train/2_nicolas_27.wav   371  of  1500
# File: ./digit_dataset/train/2_nicolas_28.wav   372  of  1500
# File: ./digit_dataset/train/2_nicolas_29.wav   373  of  1500
# File: ./digit_dataset/train/2_nicolas_3.wav   374  of  1500
# File: ./digit_dataset/train/2_nicolas_30.wav   375  of  1500
# File: ./digit_dataset/train/2_nicolas_31.wav   376  of  1500
# File: ./digit_dataset/train/2_nicolas_32.wav   377  of  1500
# File: ./digit_dataset/train/2_nicolas_33.wav   378  of  1500
# File: ./digit_dataset/train/2_nicolas_34.wav   379  of  1500
# File: ./digit_dataset/train/2_nicolas_35.wav   380  of  1500
# File: ./digit_dataset/train/2_nicolas_36.wav   381  of  1500
# File: ./digit_dataset/train/2_nicolas_37.wav   382  of  1500
# File: ./digit_dataset/train/2_nicolas_38.wav   383  of  1500
# File: ./digit_dataset/train/2_nicolas_39.wav   384  of  1500
# File: ./digit_dataset/train/2_nicolas_4.wav   385  of  1500
# File: ./digit_dataset/train/2_nicolas_40.wav   386  of  1500
# File: ./digit_dataset/train/2_nicolas_41.wav   387  of  1500
# File: ./digit_dataset/train/2_nicolas_42.wav   388  of  1500
# File: ./digit_dataset/train/2_nicolas_43.wav   389  of  1500
# File: ./digit_dataset/train/2_nicolas_44.wav   390  of  1500
# File: ./digit_dataset/train/2_nicolas_45.wav   391  of  1500
# File: ./digit_dataset/train/2_nicolas_46.wav   392  of  1500
# File: ./digit_dataset/train/2_nicolas_47.wav   393  of  1500
# File: ./digit_dataset/train/2_nicolas_48.wav   394  of  1500
# File: ./digit_dataset/train/2_nicolas_49.wav   395  of  1500
# File: ./digit_dataset/train/2_nicolas_5.wav   396  of  1500
# File: ./digit_dataset/train/2_nicolas_6.wav   397  of  1500
# File: ./digit_dataset/train/2_nicolas_7.wav   398  of  1500
# File: ./digit_dataset/train/2_nicolas_8.wav   399  of  1500
# File: ./digit_dataset/train/2_nicolas_9.wav   400  of  1500
# File: ./digit_dataset/train/2_theo_0.wav   401  of  1500
# File: ./digit_dataset/train/2_theo_1.wav   402  of  1500
# File: ./digit_dataset/train/2_theo_10.wav   403  of  1500
# File: ./digit_dataset/train/2_theo_11.wav   404  of  1500
# File: ./digit_dataset/train/2_theo_12.wav   405  of  1500
# File: ./digit_dataset/train/2_theo_13.wav   406  of  1500
# File: ./digit_dataset/train/2_theo_14.wav   407  of  1500
# File: ./digit_dataset/train/2_theo_15.wav   408  of  1500
# File: ./digit_dataset/train/2_theo_16.wav   409  of  1500
# File: ./digit_dataset/train/2_theo_17.wav   410  of  1500
# File: ./digit_dataset/train/2_theo_18.wav   411  of  1500
# File: ./digit_dataset/train/2_theo_19.wav   412  of  1500
# File: ./digit_dataset/train/2_theo_2.wav   413  of  1500
# File: ./digit_dataset/train/2_theo_20.wav   414  of  1500
# File: ./digit_dataset/train/2_theo_21.wav   415  of  1500
# File: ./digit_dataset/train/2_theo_22.wav   416  of  1500
# File: ./digit_dataset/train/2_theo_23.wav   417  of  1500
# File: ./digit_dataset/train/2_theo_24.wav   418  of  1500
# File: ./digit_dataset/train/2_theo_25.wav   419  of  1500
# File: ./digit_dataset/train/2_theo_26.wav   420  of  1500
# File: ./digit_dataset/train/2_theo_27.wav   421  of  1500
# File: ./digit_dataset/train/2_theo_28.wav   422  of  1500
# File: ./digit_dataset/train/2_theo_29.wav   423  of  1500
# File: ./digit_dataset/train/2_theo_3.wav   424  of  1500
# File: ./digit_dataset/train/2_theo_30.wav   425  of  1500
# File: ./digit_dataset/train/2_theo_31.wav   426  of  1500
# File: ./digit_dataset/train/2_theo_32.wav   427  of  1500
# File: ./digit_dataset/train/2_theo_33.wav   428  of  1500
# File: ./digit_dataset/train/2_theo_34.wav   429  of  1500
# File: ./digit_dataset/train/2_theo_35.wav   430  of  1500
# File: ./digit_dataset/train/2_theo_36.wav   431  of  1500
# File: ./digit_dataset/train/2_theo_37.wav   432  of  1500
# File: ./digit_dataset/train/2_theo_38.wav   433  of  1500
# File: ./digit_dataset/train/2_theo_39.wav   434  of  1500
# File: ./digit_dataset/train/2_theo_4.wav   435  of  1500
# File: ./digit_dataset/train/2_theo_40.wav   436  of  1500
# File: ./digit_dataset/train/2_theo_41.wav   437  of  1500
# File: ./digit_dataset/train/2_theo_42.wav   438  of  1500
# File: ./digit_dataset/train/2_theo_43.wav   439  of  1500
# File: ./digit_dataset/train/2_theo_44.wav   440  of  1500
# File: ./digit_dataset/train/2_theo_45.wav   441  of  1500
# File: ./digit_dataset/train/2_theo_46.wav   442  of  1500
# File: ./digit_dataset/train/2_theo_47.wav   443  of  1500
# File: ./digit_dataset/train/2_theo_48.wav   444  of  1500
# File: ./digit_dataset/train/2_theo_49.wav   445  of  1500
# File: ./digit_dataset/train/2_theo_5.wav   446  of  1500
# File: ./digit_dataset/train/2_theo_6.wav   447  of  1500
# File: ./digit_dataset/train/2_theo_7.wav   448  of  1500
# File: ./digit_dataset/train/2_theo_8.wav   449  of  1500
# File: ./digit_dataset/train/2_theo_9.wav   450  of  1500
# File: ./digit_dataset/train/3_jackson_0.wav   451  of  1500
# File: ./digit_dataset/train/3_jackson_1.wav   452  of  1500
# File: ./digit_dataset/train/3_jackson_10.wav   453  of  1500
# File: ./digit_dataset/train/3_jackson_11.wav   454  of  1500
# File: ./digit_dataset/train/3_jackson_12.wav   455  of  1500
# File: ./digit_dataset/train/3_jackson_13.wav   456  of  1500
# File: ./digit_dataset/train/3_jackson_14.wav   457  of  1500
# File: ./digit_dataset/train/3_jackson_15.wav   458  of  1500
# File: ./digit_dataset/train/3_jackson_16.wav   459  of  1500
# File: ./digit_dataset/train/3_jackson_17.wav   460  of  1500
# File: ./digit_dataset/train/3_jackson_18.wav   461  of  1500
# File: ./digit_dataset/train/3_jackson_19.wav   462  of  1500
# File: ./digit_dataset/train/3_jackson_2.wav   463  of  1500
# File: ./digit_dataset/train/3_jackson_20.wav   464  of  1500
# File: ./digit_dataset/train/3_jackson_21.wav   465  of  1500
# File: ./digit_dataset/train/3_jackson_22.wav   466  of  1500
# File: ./digit_dataset/train/3_jackson_23.wav   467  of  1500
# File: ./digit_dataset/train/3_jackson_24.wav   468  of  1500
# File: ./digit_dataset/train/3_jackson_25.wav   469  of  1500
# File: ./digit_dataset/train/3_jackson_26.wav   470  of  1500
# File: ./digit_dataset/train/3_jackson_27.wav   471  of  1500
# File: ./digit_dataset/train/3_jackson_28.wav   472  of  1500
# File: ./digit_dataset/train/3_jackson_29.wav   473  of  1500
# File: ./digit_dataset/train/3_jackson_3.wav   474  of  1500
# File: ./digit_dataset/train/3_jackson_30.wav   475  of  1500
# File: ./digit_dataset/train/3_jackson_31.wav   476  of  1500
# File: ./digit_dataset/train/3_jackson_32.wav   477  of  1500
# File: ./digit_dataset/train/3_jackson_33.wav   478  of  1500
# File: ./digit_dataset/train/3_jackson_34.wav   479  of  1500
# File: ./digit_dataset/train/3_jackson_35.wav   480  of  1500
# File: ./digit_dataset/train/3_jackson_36.wav   481  of  1500
# File: ./digit_dataset/train/3_jackson_37.wav   482  of  1500
# File: ./digit_dataset/train/3_jackson_38.wav   483  of  1500
# File: ./digit_dataset/train/3_jackson_39.wav   484  of  1500
# File: ./digit_dataset/train/3_jackson_4.wav   485  of  1500
# File: ./digit_dataset/train/3_jackson_40.wav   486  of  1500
# File: ./digit_dataset/train/3_jackson_41.wav   487  of  1500
# File: ./digit_dataset/train/3_jackson_42.wav   488  of  1500
# File: ./digit_dataset/train/3_jackson_43.wav   489  of  1500
# File: ./digit_dataset/train/3_jackson_44.wav   490  of  1500
# File: ./digit_dataset/train/3_jackson_45.wav   491  of  1500
# File: ./digit_dataset/train/3_jackson_46.wav   492  of  1500
# File: ./digit_dataset/train/3_jackson_47.wav   493  of  1500
# File: ./digit_dataset/train/3_jackson_48.wav   494  of  1500
# File: ./digit_dataset/train/3_jackson_49.wav   495  of  1500
# File: ./digit_dataset/train/3_jackson_5.wav   496  of  1500
# File: ./digit_dataset/train/3_jackson_6.wav   497  of  1500
# File: ./digit_dataset/train/3_jackson_7.wav   498  of  1500
# File: ./digit_dataset/train/3_jackson_8.wav   499  of  1500
# File: ./digit_dataset/train/3_jackson_9.wav   500  of  1500
# File: ./digit_dataset/train/3_nicolas_0.wav   501  of  1500
# File: ./digit_dataset/train/3_nicolas_1.wav   502  of  1500
# File: ./digit_dataset/train/3_nicolas_10.wav   503  of  1500
# File: ./digit_dataset/train/3_nicolas_11.wav   504  of  1500
# File: ./digit_dataset/train/3_nicolas_12.wav   505  of  1500
# File: ./digit_dataset/train/3_nicolas_13.wav   506  of  1500
# File: ./digit_dataset/train/3_nicolas_14.wav   507  of  1500
# File: ./digit_dataset/train/3_nicolas_15.wav   508  of  1500
# File: ./digit_dataset/train/3_nicolas_16.wav   509  of  1500
# File: ./digit_dataset/train/3_nicolas_17.wav   510  of  1500
# File: ./digit_dataset/train/3_nicolas_18.wav   511  of  1500
# File: ./digit_dataset/train/3_nicolas_19.wav   512  of  1500
# File: ./digit_dataset/train/3_nicolas_2.wav   513  of  1500
# File: ./digit_dataset/train/3_nicolas_20.wav   514  of  1500
# File: ./digit_dataset/train/3_nicolas_21.wav   515  of  1500
# File: ./digit_dataset/train/3_nicolas_22.wav   516  of  1500
# File: ./digit_dataset/train/3_nicolas_23.wav   517  of  1500
# File: ./digit_dataset/train/3_nicolas_24.wav   518  of  1500
# File: ./digit_dataset/train/3_nicolas_25.wav   519  of  1500
# File: ./digit_dataset/train/3_nicolas_26.wav   520  of  1500
# File: ./digit_dataset/train/3_nicolas_27.wav   521  of  1500
# File: ./digit_dataset/train/3_nicolas_28.wav   522  of  1500
# File: ./digit_dataset/train/3_nicolas_29.wav   523  of  1500
# File: ./digit_dataset/train/3_nicolas_3.wav   524  of  1500
# File: ./digit_dataset/train/3_nicolas_30.wav   525  of  1500
# File: ./digit_dataset/train/3_nicolas_31.wav   526  of  1500
# File: ./digit_dataset/train/3_nicolas_32.wav   527  of  1500
# File: ./digit_dataset/train/3_nicolas_33.wav   528  of  1500
# File: ./digit_dataset/train/3_nicolas_34.wav   529  of  1500
# File: ./digit_dataset/train/3_nicolas_35.wav   530  of  1500
# File: ./digit_dataset/train/3_nicolas_36.wav   531  of  1500
# File: ./digit_dataset/train/3_nicolas_37.wav   532  of  1500
# File: ./digit_dataset/train/3_nicolas_38.wav   533  of  1500
# File: ./digit_dataset/train/3_nicolas_39.wav   534  of  1500
# File: ./digit_dataset/train/3_nicolas_4.wav   535  of  1500
# File: ./digit_dataset/train/3_nicolas_40.wav   536  of  1500
# File: ./digit_dataset/train/3_nicolas_41.wav   537  of  1500
# File: ./digit_dataset/train/3_nicolas_42.wav   538  of  1500
# File: ./digit_dataset/train/3_nicolas_43.wav   539  of  1500
# File: ./digit_dataset/train/3_nicolas_44.wav   540  of  1500
# File: ./digit_dataset/train/3_nicolas_45.wav   541  of  1500
# File: ./digit_dataset/train/3_nicolas_46.wav   542  of  1500
# File: ./digit_dataset/train/3_nicolas_47.wav   543  of  1500
# File: ./digit_dataset/train/3_nicolas_48.wav   544  of  1500
# File: ./digit_dataset/train/3_nicolas_49.wav   545  of  1500
# File: ./digit_dataset/train/3_nicolas_5.wav   546  of  1500
# File: ./digit_dataset/train/3_nicolas_6.wav   547  of  1500
# File: ./digit_dataset/train/3_nicolas_7.wav   548  of  1500
# File: ./digit_dataset/train/3_nicolas_8.wav   549  of  1500
# File: ./digit_dataset/train/3_nicolas_9.wav   550  of  1500
# File: ./digit_dataset/train/3_theo_0.wav   551  of  1500
# File: ./digit_dataset/train/3_theo_1.wav   552  of  1500
# File: ./digit_dataset/train/3_theo_10.wav   553  of  1500
# File: ./digit_dataset/train/3_theo_11.wav   554  of  1500
# File: ./digit_dataset/train/3_theo_12.wav   555  of  1500
# File: ./digit_dataset/train/3_theo_13.wav   556  of  1500
# File: ./digit_dataset/train/3_theo_14.wav   557  of  1500
# File: ./digit_dataset/train/3_theo_15.wav   558  of  1500
# File: ./digit_dataset/train/3_theo_16.wav   559  of  1500
# File: ./digit_dataset/train/3_theo_17.wav   560  of  1500
# File: ./digit_dataset/train/3_theo_18.wav   561  of  1500
# File: ./digit_dataset/train/3_theo_19.wav   562  of  1500
# File: ./digit_dataset/train/3_theo_2.wav   563  of  1500
# File: ./digit_dataset/train/3_theo_20.wav   564  of  1500
# File: ./digit_dataset/train/3_theo_21.wav   565  of  1500
# File: ./digit_dataset/train/3_theo_22.wav   566  of  1500
# File: ./digit_dataset/train/3_theo_23.wav   567  of  1500
# File: ./digit_dataset/train/3_theo_24.wav   568  of  1500
# File: ./digit_dataset/train/3_theo_25.wav   569  of  1500
# File: ./digit_dataset/train/3_theo_26.wav   570  of  1500
# File: ./digit_dataset/train/3_theo_27.wav   571  of  1500
# File: ./digit_dataset/train/3_theo_28.wav   572  of  1500
# File: ./digit_dataset/train/3_theo_29.wav   573  of  1500
# File: ./digit_dataset/train/3_theo_3.wav   574  of  1500
# File: ./digit_dataset/train/3_theo_30.wav   575  of  1500
# File: ./digit_dataset/train/3_theo_31.wav   576  of  1500
# File: ./digit_dataset/train/3_theo_32.wav   577  of  1500
# File: ./digit_dataset/train/3_theo_33.wav   578  of  1500
# File: ./digit_dataset/train/3_theo_34.wav   579  of  1500
# File: ./digit_dataset/train/3_theo_35.wav   580  of  1500
# File: ./digit_dataset/train/3_theo_36.wav   581  of  1500
# File: ./digit_dataset/train/3_theo_37.wav   582  of  1500
# File: ./digit_dataset/train/3_theo_38.wav   583  of  1500
# File: ./digit_dataset/train/3_theo_39.wav   584  of  1500
# File: ./digit_dataset/train/3_theo_4.wav   585  of  1500
# File: ./digit_dataset/train/3_theo_40.wav   586  of  1500
# File: ./digit_dataset/train/3_theo_41.wav   587  of  1500
# File: ./digit_dataset/train/3_theo_42.wav   588  of  1500
# File: ./digit_dataset/train/3_theo_43.wav   589  of  1500
# File: ./digit_dataset/train/3_theo_44.wav   590  of  1500
# File: ./digit_dataset/train/3_theo_45.wav   591  of  1500
# File: ./digit_dataset/train/3_theo_46.wav   592  of  1500
# File: ./digit_dataset/train/3_theo_47.wav   593  of  1500
# File: ./digit_dataset/train/3_theo_48.wav   594  of  1500
# File: ./digit_dataset/train/3_theo_49.wav   595  of  1500
# File: ./digit_dataset/train/3_theo_5.wav   596  of  1500
# File: ./digit_dataset/train/3_theo_6.wav   597  of  1500
# File: ./digit_dataset/train/3_theo_7.wav   598  of  1500
# File: ./digit_dataset/train/3_theo_8.wav   599  of  1500
# File: ./digit_dataset/train/3_theo_9.wav   600  of  1500
# File: ./digit_dataset/train/4_jackson_0.wav   601  of  1500
# File: ./digit_dataset/train/4_jackson_1.wav   602  of  1500
# File: ./digit_dataset/train/4_jackson_10.wav   603  of  1500
# File: ./digit_dataset/train/4_jackson_11.wav   604  of  1500
# File: ./digit_dataset/train/4_jackson_12.wav   605  of  1500
# File: ./digit_dataset/train/4_jackson_13.wav   606  of  1500
# File: ./digit_dataset/train/4_jackson_14.wav   607  of  1500
# File: ./digit_dataset/train/4_jackson_15.wav   608  of  1500
# File: ./digit_dataset/train/4_jackson_16.wav   609  of  1500
# File: ./digit_dataset/train/4_jackson_17.wav   610  of  1500
# File: ./digit_dataset/train/4_jackson_18.wav   611  of  1500
# File: ./digit_dataset/train/4_jackson_19.wav   612  of  1500
# File: ./digit_dataset/train/4_jackson_2.wav   613  of  1500
# File: ./digit_dataset/train/4_jackson_20.wav   614  of  1500
# File: ./digit_dataset/train/4_jackson_21.wav   615  of  1500
# File: ./digit_dataset/train/4_jackson_22.wav   616  of  1500
# File: ./digit_dataset/train/4_jackson_23.wav   617  of  1500
# File: ./digit_dataset/train/4_jackson_24.wav   618  of  1500
# File: ./digit_dataset/train/4_jackson_25.wav   619  of  1500
# File: ./digit_dataset/train/4_jackson_26.wav   620  of  1500
# File: ./digit_dataset/train/4_jackson_27.wav   621  of  1500
# File: ./digit_dataset/train/4_jackson_28.wav   622  of  1500
# File: ./digit_dataset/train/4_jackson_29.wav   623  of  1500
# File: ./digit_dataset/train/4_jackson_3.wav   624  of  1500
# File: ./digit_dataset/train/4_jackson_30.wav   625  of  1500
# File: ./digit_dataset/train/4_jackson_31.wav   626  of  1500
# File: ./digit_dataset/train/4_jackson_32.wav   627  of  1500
# File: ./digit_dataset/train/4_jackson_33.wav   628  of  1500
# File: ./digit_dataset/train/4_jackson_34.wav   629  of  1500
# File: ./digit_dataset/train/4_jackson_35.wav   630  of  1500
# File: ./digit_dataset/train/4_jackson_36.wav   631  of  1500
# File: ./digit_dataset/train/4_jackson_37.wav   632  of  1500
# File: ./digit_dataset/train/4_jackson_38.wav   633  of  1500
# File: ./digit_dataset/train/4_jackson_39.wav   634  of  1500
# File: ./digit_dataset/train/4_jackson_4.wav   635  of  1500
# File: ./digit_dataset/train/4_jackson_40.wav   636  of  1500
# File: ./digit_dataset/train/4_jackson_41.wav   637  of  1500
# File: ./digit_dataset/train/4_jackson_42.wav   638  of  1500
# File: ./digit_dataset/train/4_jackson_43.wav   639  of  1500
# File: ./digit_dataset/train/4_jackson_44.wav   640  of  1500
# File: ./digit_dataset/train/4_jackson_45.wav   641  of  1500
# File: ./digit_dataset/train/4_jackson_46.wav   642  of  1500
# File: ./digit_dataset/train/4_jackson_47.wav   643  of  1500
# File: ./digit_dataset/train/4_jackson_48.wav   644  of  1500
# File: ./digit_dataset/train/4_jackson_49.wav   645  of  1500
# File: ./digit_dataset/train/4_jackson_5.wav   646  of  1500
# File: ./digit_dataset/train/4_jackson_6.wav   647  of  1500
# File: ./digit_dataset/train/4_jackson_7.wav   648  of  1500
# File: ./digit_dataset/train/4_jackson_8.wav   649  of  1500
# File: ./digit_dataset/train/4_jackson_9.wav   650  of  1500
# File: ./digit_dataset/train/4_nicolas_0.wav   651  of  1500
# File: ./digit_dataset/train/4_nicolas_1.wav   652  of  1500
# File: ./digit_dataset/train/4_nicolas_10.wav   653  of  1500
# File: ./digit_dataset/train/4_nicolas_11.wav   654  of  1500
# File: ./digit_dataset/train/4_nicolas_12.wav   655  of  1500
# File: ./digit_dataset/train/4_nicolas_13.wav   656  of  1500
# File: ./digit_dataset/train/4_nicolas_14.wav   657  of  1500
# File: ./digit_dataset/train/4_nicolas_15.wav   658  of  1500
# File: ./digit_dataset/train/4_nicolas_16.wav   659  of  1500
# File: ./digit_dataset/train/4_nicolas_17.wav   660  of  1500
# File: ./digit_dataset/train/4_nicolas_18.wav   661  of  1500
# File: ./digit_dataset/train/4_nicolas_19.wav   662  of  1500
# File: ./digit_dataset/train/4_nicolas_2.wav   663  of  1500
# File: ./digit_dataset/train/4_nicolas_20.wav   664  of  1500
# File: ./digit_dataset/train/4_nicolas_21.wav   665  of  1500
# File: ./digit_dataset/train/4_nicolas_22.wav   666  of  1500
# File: ./digit_dataset/train/4_nicolas_23.wav   667  of  1500
# File: ./digit_dataset/train/4_nicolas_24.wav   668  of  1500
# File: ./digit_dataset/train/4_nicolas_25.wav   669  of  1500
# File: ./digit_dataset/train/4_nicolas_26.wav   670  of  1500
# File: ./digit_dataset/train/4_nicolas_27.wav   671  of  1500
# File: ./digit_dataset/train/4_nicolas_28.wav   672  of  1500
# File: ./digit_dataset/train/4_nicolas_29.wav   673  of  1500
# File: ./digit_dataset/train/4_nicolas_3.wav   674  of  1500
# File: ./digit_dataset/train/4_nicolas_30.wav   675  of  1500
# File: ./digit_dataset/train/4_nicolas_31.wav   676  of  1500
# File: ./digit_dataset/train/4_nicolas_32.wav   677  of  1500
# File: ./digit_dataset/train/4_nicolas_33.wav   678  of  1500
# File: ./digit_dataset/train/4_nicolas_34.wav   679  of  1500
# File: ./digit_dataset/train/4_nicolas_35.wav   680  of  1500
# File: ./digit_dataset/train/4_nicolas_36.wav   681  of  1500
# File: ./digit_dataset/train/4_nicolas_37.wav   682  of  1500
# File: ./digit_dataset/train/4_nicolas_38.wav   683  of  1500
# File: ./digit_dataset/train/4_nicolas_39.wav   684  of  1500
# File: ./digit_dataset/train/4_nicolas_4.wav   685  of  1500
# File: ./digit_dataset/train/4_nicolas_40.wav   686  of  1500
# File: ./digit_dataset/train/4_nicolas_41.wav   687  of  1500
# File: ./digit_dataset/train/4_nicolas_42.wav   688  of  1500
# File: ./digit_dataset/train/4_nicolas_43.wav   689  of  1500
# File: ./digit_dataset/train/4_nicolas_44.wav   690  of  1500
# File: ./digit_dataset/train/4_nicolas_45.wav   691  of  1500
# File: ./digit_dataset/train/4_nicolas_46.wav   692  of  1500
# File: ./digit_dataset/train/4_nicolas_47.wav   693  of  1500
# File: ./digit_dataset/train/4_nicolas_48.wav   694  of  1500
# File: ./digit_dataset/train/4_nicolas_49.wav   695  of  1500
# File: ./digit_dataset/train/4_nicolas_5.wav   696  of  1500
# File: ./digit_dataset/train/4_nicolas_6.wav   697  of  1500
# File: ./digit_dataset/train/4_nicolas_7.wav   698  of  1500
# File: ./digit_dataset/train/4_nicolas_8.wav   699  of  1500
# File: ./digit_dataset/train/4_nicolas_9.wav   700  of  1500
# File: ./digit_dataset/train/4_theo_0.wav   701  of  1500
# File: ./digit_dataset/train/4_theo_1.wav   702  of  1500
# File: ./digit_dataset/train/4_theo_10.wav   703  of  1500
# File: ./digit_dataset/train/4_theo_11.wav   704  of  1500
# File: ./digit_dataset/train/4_theo_12.wav   705  of  1500
# File: ./digit_dataset/train/4_theo_13.wav   706  of  1500
# File: ./digit_dataset/train/4_theo_14.wav   707  of  1500
# File: ./digit_dataset/train/4_theo_15.wav   708  of  1500
# File: ./digit_dataset/train/4_theo_16.wav   709  of  1500
# File: ./digit_dataset/train/4_theo_17.wav   710  of  1500
# File: ./digit_dataset/train/4_theo_18.wav   711  of  1500
# File: ./digit_dataset/train/4_theo_19.wav   712  of  1500
# File: ./digit_dataset/train/4_theo_2.wav   713  of  1500
# File: ./digit_dataset/train/4_theo_20.wav   714  of  1500
# File: ./digit_dataset/train/4_theo_21.wav   715  of  1500
# File: ./digit_dataset/train/4_theo_22.wav   716  of  1500
# File: ./digit_dataset/train/4_theo_23.wav   717  of  1500
# File: ./digit_dataset/train/4_theo_24.wav   718  of  1500
# File: ./digit_dataset/train/4_theo_25.wav   719  of  1500
# File: ./digit_dataset/train/4_theo_26.wav   720  of  1500
# File: ./digit_dataset/train/4_theo_27.wav   721  of  1500
# File: ./digit_dataset/train/4_theo_28.wav   722  of  1500
# File: ./digit_dataset/train/4_theo_29.wav   723  of  1500
# File: ./digit_dataset/train/4_theo_3.wav   724  of  1500
# File: ./digit_dataset/train/4_theo_30.wav   725  of  1500
# File: ./digit_dataset/train/4_theo_31.wav   726  of  1500
# File: ./digit_dataset/train/4_theo_32.wav   727  of  1500
# File: ./digit_dataset/train/4_theo_33.wav   728  of  1500
# File: ./digit_dataset/train/4_theo_34.wav   729  of  1500
# File: ./digit_dataset/train/4_theo_35.wav   730  of  1500
# File: ./digit_dataset/train/4_theo_36.wav   731  of  1500
# File: ./digit_dataset/train/4_theo_37.wav   732  of  1500
# File: ./digit_dataset/train/4_theo_38.wav   733  of  1500
# File: ./digit_dataset/train/4_theo_39.wav   734  of  1500
# File: ./digit_dataset/train/4_theo_4.wav   735  of  1500
# File: ./digit_dataset/train/4_theo_40.wav   736  of  1500
# File: ./digit_dataset/train/4_theo_41.wav   737  of  1500
# File: ./digit_dataset/train/4_theo_42.wav   738  of  1500
# File: ./digit_dataset/train/4_theo_43.wav   739  of  1500
# File: ./digit_dataset/train/4_theo_44.wav   740  of  1500
# File: ./digit_dataset/train/4_theo_45.wav   741  of  1500
# File: ./digit_dataset/train/4_theo_46.wav   742  of  1500
# File: ./digit_dataset/train/4_theo_47.wav   743  of  1500
# File: ./digit_dataset/train/4_theo_48.wav   744  of  1500
# File: ./digit_dataset/train/4_theo_49.wav   745  of  1500
# File: ./digit_dataset/train/4_theo_5.wav   746  of  1500
# File: ./digit_dataset/train/4_theo_6.wav   747  of  1500
# File: ./digit_dataset/train/4_theo_7.wav   748  of  1500
# File: ./digit_dataset/train/4_theo_8.wav   749  of  1500
# File: ./digit_dataset/train/4_theo_9.wav   750  of  1500
# File: ./digit_dataset/train/5_jackson_0.wav   751  of  1500
# File: ./digit_dataset/train/5_jackson_1.wav   752  of  1500
# File: ./digit_dataset/train/5_jackson_10.wav   753  of  1500
# File: ./digit_dataset/train/5_jackson_11.wav   754  of  1500
# File: ./digit_dataset/train/5_jackson_12.wav   755  of  1500
# File: ./digit_dataset/train/5_jackson_13.wav   756  of  1500
# File: ./digit_dataset/train/5_jackson_14.wav   757  of  1500
# File: ./digit_dataset/train/5_jackson_15.wav   758  of  1500
# File: ./digit_dataset/train/5_jackson_16.wav   759  of  1500
# File: ./digit_dataset/train/5_jackson_17.wav   760  of  1500
# File: ./digit_dataset/train/5_jackson_18.wav   761  of  1500
# File: ./digit_dataset/train/5_jackson_19.wav   762  of  1500
# File: ./digit_dataset/train/5_jackson_2.wav   763  of  1500
# File: ./digit_dataset/train/5_jackson_20.wav   764  of  1500
# File: ./digit_dataset/train/5_jackson_21.wav   765  of  1500
# File: ./digit_dataset/train/5_jackson_22.wav   766  of  1500
# File: ./digit_dataset/train/5_jackson_23.wav   767  of  1500
# File: ./digit_dataset/train/5_jackson_24.wav   768  of  1500
# File: ./digit_dataset/train/5_jackson_25.wav   769  of  1500
# File: ./digit_dataset/train/5_jackson_26.wav   770  of  1500
# File: ./digit_dataset/train/5_jackson_27.wav   771  of  1500
# File: ./digit_dataset/train/5_jackson_28.wav   772  of  1500
# File: ./digit_dataset/train/5_jackson_29.wav   773  of  1500
# File: ./digit_dataset/train/5_jackson_3.wav   774  of  1500
# File: ./digit_dataset/train/5_jackson_30.wav   775  of  1500
# File: ./digit_dataset/train/5_jackson_31.wav   776  of  1500
# File: ./digit_dataset/train/5_jackson_32.wav   777  of  1500
# File: ./digit_dataset/train/5_jackson_33.wav   778  of  1500
# File: ./digit_dataset/train/5_jackson_34.wav   779  of  1500
# File: ./digit_dataset/train/5_jackson_35.wav   780  of  1500
# File: ./digit_dataset/train/5_jackson_36.wav   781  of  1500
# File: ./digit_dataset/train/5_jackson_37.wav   782  of  1500
# File: ./digit_dataset/train/5_jackson_38.wav   783  of  1500
# File: ./digit_dataset/train/5_jackson_39.wav   784  of  1500
# File: ./digit_dataset/train/5_jackson_4.wav   785  of  1500
# File: ./digit_dataset/train/5_jackson_40.wav   786  of  1500
# File: ./digit_dataset/train/5_jackson_41.wav   787  of  1500
# File: ./digit_dataset/train/5_jackson_42.wav   788  of  1500
# File: ./digit_dataset/train/5_jackson_43.wav   789  of  1500
# File: ./digit_dataset/train/5_jackson_44.wav   790  of  1500
# File: ./digit_dataset/train/5_jackson_45.wav   791  of  1500
# File: ./digit_dataset/train/5_jackson_46.wav   792  of  1500
# File: ./digit_dataset/train/5_jackson_47.wav   793  of  1500
# File: ./digit_dataset/train/5_jackson_48.wav   794  of  1500
# File: ./digit_dataset/train/5_jackson_49.wav   795  of  1500
# File: ./digit_dataset/train/5_jackson_5.wav   796  of  1500
# File: ./digit_dataset/train/5_jackson_6.wav   797  of  1500
# File: ./digit_dataset/train/5_jackson_7.wav   798  of  1500
# File: ./digit_dataset/train/5_jackson_8.wav   799  of  1500
# File: ./digit_dataset/train/5_jackson_9.wav   800  of  1500
# File: ./digit_dataset/train/5_nicolas_0.wav   801  of  1500
# File: ./digit_dataset/train/5_nicolas_1.wav   802  of  1500
# File: ./digit_dataset/train/5_nicolas_10.wav   803  of  1500
# ...
# File: ./digit_dataset/train/8_jackson_47.wav   1243  of  1500
# File: ./digit_dataset/train/8_jackson_48.wav   1244  of  1500
# File: ./digit_dataset/train/8_jackson_49.wav   1245  of  1500
# File: ./digit_dataset/train/8_jackson_5.wav   1246  of  1500
# File: ./digit_dataset/train/8_jackson_6.wav   1247  of  1500
# File: ./digit_dataset/train/8_jackson_7.wav   1248  of  1500
# File: ./digit_dataset/train/8_jackson_8.wav   1249  of  1500
# File: ./digit_dataset/train/8_jackson_9.wav   1250  of  1500
# File: ./digit_dataset/train/8_nicolas_0.wav   1251  of  1500
# File: ./digit_dataset/train/8_nicolas_1.wav   1252  of  1500
# File: ./digit_dataset/train/8_nicolas_10.wav   1253  of  1500
# File: ./digit_dataset/train/8_nicolas_11.wav   1254  of  1500
# File: ./digit_dataset/train/8_nicolas_12.wav   1255  of  1500
# File: ./digit_dataset/train/8_nicolas_13.wav   1256  of  1500
# File: ./digit_dataset/train/8_nicolas_14.wav   1257  of  1500
# File: ./digit_dataset/train/8_nicolas_15.wav   1258  of  1500
# File: ./digit_dataset/train/8_nicolas_16.wav   1259  of  1500
# File: ./digit_dataset/train/8_nicolas_17.wav   1260  of  1500
# File: ./digit_dataset/train/8_nicolas_18.wav   1261  of  1500
# File: ./digit_dataset/train/8_nicolas_19.wav   1262  of  1500
# File: ./digit_dataset/train/8_nicolas_2.wav   1263  of  1500
# File: ./digit_dataset/train/8_nicolas_20.wav   1264  of  1500
# File: ./digit_dataset/train/8_nicolas_21.wav   1265  of  1500
# File: ./digit_dataset/train/8_nicolas_22.wav   1266  of  1500
# File: ./digit_dataset/train/8_nicolas_23.wav   1267  of  1500
# File: ./digit_dataset/train/8_nicolas_24.wav   1268  of  1500
# File: ./digit_dataset/train/8_nicolas_25.wav   1269  of  1500
# File: ./digit_dataset/train/8_nicolas_26.wav   1270  of  1500
# File: ./digit_dataset/train/8_nicolas_27.wav   1271  of  1500
# File: ./digit_dataset/train/8_nicolas_28.wav   1272  of  1500
# File: ./digit_dataset/train/8_nicolas_29.wav   1273  of  1500
# File: ./digit_dataset/train/8_nicolas_3.wav   1274  of  1500
# File: ./digit_dataset/train/8_nicolas_30.wav   1275  of  1500
# File: ./digit_dataset/train/8_nicolas_31.wav   1276  of  1500
# File: ./digit_dataset/train/8_nicolas_32.wav   1277  of  1500
# File: ./digit_dataset/train/8_nicolas_33.wav   1278  of  1500
# File: ./digit_dataset/train/8_nicolas_34.wav   1279  of  1500
# File: ./digit_dataset/train/8_nicolas_35.wav   1280  of  1500
# File: ./digit_dataset/train/8_nicolas_36.wav   1281  of  1500
# File: ./digit_dataset/train/8_nicolas_37.wav   1282  of  1500
# File: ./digit_dataset/train/8_nicolas_38.wav   1283  of  1500
# File: ./digit_dataset/train/8_nicolas_39.wav   1284  of  1500
# File: ./digit_dataset/train/8_nicolas_4.wav   1285  of  1500
# File: ./digit_dataset/train/8_nicolas_40.wav   1286  of  1500
# File: ./digit_dataset/train/8_nicolas_41.wav   1287  of  1500
# File: ./digit_dataset/train/8_nicolas_42.wav   1288  of  1500
# File: ./digit_dataset/train/8_nicolas_43.wav   1289  of  1500
# File: ./digit_dataset/train/8_nicolas_44.wav   1290  of  1500
# File: ./digit_dataset/train/8_nicolas_45.wav   1291  of  1500
# File: ./digit_dataset/train/8_nicolas_46.wav   1292  of  1500
# File: ./digit_dataset/train/8_nicolas_47.wav   1293  of  1500
# File: ./digit_dataset/train/8_nicolas_48.wav   1294  of  1500
# File: ./digit_dataset/train/8_nicolas_49.wav   1295  of  1500
# File: ./digit_dataset/train/8_nicolas_5.wav   1296  of  1500
# File: ./digit_dataset/train/8_nicolas_6.wav   1297  of  1500
# File: ./digit_dataset/train/8_nicolas_7.wav   1298  of  1500
# File: ./digit_dataset/train/8_nicolas_8.wav   1299  of  1500
# File: ./digit_dataset/train/8_nicolas_9.wav   1300  of  1500
# File: ./digit_dataset/train/8_theo_0.wav   1301  of  1500
# File: ./digit_dataset/train/8_theo_1.wav   1302  of  1500
# File: ./digit_dataset/train/8_theo_10.wav   1303  of  1500
# File: ./digit_dataset/train/8_theo_11.wav   1304  of  1500
# File: ./digit_dataset/train/8_theo_12.wav   1305  of  1500
# File: ./digit_dataset/train/8_theo_13.wav   1306  of  1500
# File: ./digit_dataset/train/8_theo_14.wav   1307  of  1500
# File: ./digit_dataset/train/8_theo_15.wav   1308  of  1500
# File: ./digit_dataset/train/8_theo_16.wav   1309  of  1500
# File: ./digit_dataset/train/8_theo_17.wav   1310  of  1500
# File: ./digit_dataset/train/8_theo_18.wav   1311  of  1500
# File: ./digit_dataset/train/8_theo_19.wav   1312  of  1500
# File: ./digit_dataset/train/8_theo_2.wav   1313  of  1500
# File: ./digit_dataset/train/8_theo_20.wav   1314  of  1500
# File: ./digit_dataset/train/8_theo_21.wav   1315  of  1500
# File: ./digit_dataset/train/8_theo_22.wav   1316  of  1500
# File: ./digit_dataset/train/8_theo_23.wav   1317  of  1500
# File: ./digit_dataset/train/8_theo_24.wav   1318  of  1500
# File: ./digit_dataset/train/8_theo_25.wav   1319  of  1500
# File: ./digit_dataset/train/8_theo_26.wav   1320  of  1500
# File: ./digit_dataset/train/8_theo_27.wav   1321  of  1500
# File: ./digit_dataset/train/8_theo_28.wav   1322  of  1500
# File: ./digit_dataset/train/8_theo_29.wav   1323  of  1500
# File: ./digit_dataset/train/8_theo_3.wav   1324  of  1500
# File: ./digit_dataset/train/8_theo_30.wav   1325  of  1500
# File: ./digit_dataset/train/8_theo_31.wav   1326  of  1500
# File: ./digit_dataset/train/8_theo_32.wav   1327  of  1500
# File: ./digit_dataset/train/8_theo_33.wav   1328  of  1500
# File: ./digit_dataset/train/8_theo_34.wav   1329  of  1500
# File: ./digit_dataset/train/8_theo_35.wav   1330  of  1500
# File: ./digit_dataset/train/8_theo_36.wav   1331  of  1500
# File: ./digit_dataset/train/8_theo_37.wav   1332  of  1500
# File: ./digit_dataset/train/8_theo_38.wav   1333  of  1500
# File: ./digit_dataset/train/8_theo_39.wav   1334  of  1500
# File: ./digit_dataset/train/8_theo_4.wav   1335  of  1500
# File: ./digit_dataset/train/8_theo_40.wav   1336  of  1500
# File: ./digit_dataset/train/8_theo_41.wav   1337  of  1500
# File: ./digit_dataset/train/8_theo_42.wav   1338  of  1500
# File: ./digit_dataset/train/8_theo_43.wav   1339  of  1500
# File: ./digit_dataset/train/8_theo_44.wav   1340  of  1500
# File: ./digit_dataset/train/8_theo_45.wav   1341  of  1500
# File: ./digit_dataset/train/8_theo_46.wav   1342  of  1500
# File: ./digit_dataset/train/8_theo_47.wav   1343  of  1500
# File: ./digit_dataset/train/8_theo_48.wav   1344  of  1500
# File: ./digit_dataset/train/8_theo_49.wav   1345  of  1500
# File: ./digit_dataset/train/8_theo_5.wav   1346  of  1500
# File: ./digit_dataset/train/8_theo_6.wav   1347  of  1500
# File: ./digit_dataset/train/8_theo_7.wav   1348  of  1500
# File: ./digit_dataset/train/8_theo_8.wav   1349  of  1500
# File: ./digit_dataset/train/8_theo_9.wav   1350  of  1500
# File: ./digit_dataset/train/9_jackson_0.wav   1351  of  1500
# File: ./digit_dataset/train/9_jackson_1.wav   1352  of  1500
# File: ./digit_dataset/train/9_jackson_10.wav   1353  of  1500
# File: ./digit_dataset/train/9_jackson_11.wav   1354  of  1500
# File: ./digit_dataset/train/9_jackson_12.wav   1355  of  1500
# File: ./digit_dataset/train/9_jackson_13.wav   1356  of  1500
# File: ./digit_dataset/train/9_jackson_14.wav   1357  of  1500
# File: ./digit_dataset/train/9_jackson_15.wav   1358  of  1500
# File: ./digit_dataset/train/9_jackson_16.wav   1359  of  1500
# File: ./digit_dataset/train/9_jackson_17.wav   1360  of  1500
# File: ./digit_dataset/train/9_jackson_18.wav   1361  of  1500
# File: ./digit_dataset/train/9_jackson_19.wav   1362  of  1500
# File: ./digit_dataset/train/9_jackson_2.wav   1363  of  1500
# File: ./digit_dataset/train/9_jackson_20.wav   1364  of  1500
# File: ./digit_dataset/train/9_jackson_21.wav   1365  of  1500
# File: ./digit_dataset/train/9_jackson_22.wav   1366  of  1500
# File: ./digit_dataset/train/9_jackson_23.wav   1367  of  1500
# File: ./digit_dataset/train/9_jackson_24.wav   1368  of  1500
# File: ./digit_dataset/train/9_jackson_25.wav   1369  of  1500
# File: ./digit_dataset/train/9_jackson_26.wav   1370  of  1500
# File: ./digit_dataset/train/9_jackson_27.wav   1371  of  1500
# File: ./digit_dataset/train/9_jackson_28.wav   1372  of  1500
# File: ./digit_dataset/train/9_jackson_29.wav   1373  of  1500
# File: ./digit_dataset/train/9_jackson_3.wav   1374  of  1500
# File: ./digit_dataset/train/9_jackson_30.wav   1375  of  1500
# File: ./digit_dataset/train/9_jackson_31.wav   1376  of  1500
# File: ./digit_dataset/train/9_jackson_32.wav   1377  of  1500
# File: ./digit_dataset/train/9_jackson_33.wav   1378  of  1500
# File: ./digit_dataset/train/9_jackson_34.wav   1379  of  1500
# File: ./digit_dataset/train/9_jackson_35.wav   1380  of  1500
# File: ./digit_dataset/train/9_jackson_36.wav   1381  of  1500
# File: ./digit_dataset/train/9_jackson_37.wav   1382  of  1500
# File: ./digit_dataset/train/9_jackson_38.wav   1383  of  1500
# File: ./digit_dataset/train/9_jackson_39.wav   1384  of  1500
# File: ./digit_dataset/train/9_jackson_4.wav   1385  of  1500
# File: ./digit_dataset/train/9_jackson_40.wav   1386  of  1500
# File: ./digit_dataset/train/9_jackson_41.wav   1387  of  1500
# File: ./digit_dataset/train/9_jackson_42.wav   1388  of  1500
# File: ./digit_dataset/train/9_jackson_43.wav   1389  of  1500
# File: ./digit_dataset/train/9_jackson_44.wav   1390  of  1500
# File: ./digit_dataset/train/9_jackson_45.wav   1391  of  1500
# File: ./digit_dataset/train/9_jackson_46.wav   1392  of  1500
# File: ./digit_dataset/train/9_jackson_47.wav   1393  of  1500
# File: ./digit_dataset/train/9_jackson_48.wav   1394  of  1500
# File: ./digit_dataset/train/9_jackson_49.wav   1395  of  1500
# File: ./digit_dataset/train/9_jackson_5.wav   1396  of  1500
# File: ./digit_dataset/train/9_jackson_6.wav   1397  of  1500
# File: ./digit_dataset/train/9_jackson_7.wav   1398  of  1500
# File: ./digit_dataset/train/9_jackson_8.wav   1399  of  1500
# File: ./digit_dataset/train/9_jackson_9.wav   1400  of  1500
# File: ./digit_dataset/train/9_nicolas_0.wav   1401  of  1500
# File: ./digit_dataset/train/9_nicolas_1.wav   1402  of  1500
# File: ./digit_dataset/train/9_nicolas_10.wav   1403  of  1500
# File: ./digit_dataset/train/9_nicolas_11.wav   1404  of  1500
# File: ./digit_dataset/train/9_nicolas_12.wav   1405  of  1500
# File: ./digit_dataset/train/9_nicolas_13.wav   1406  of  1500
# File: ./digit_dataset/train/9_nicolas_14.wav   1407  of  1500
# File: ./digit_dataset/train/9_nicolas_15.wav   1408  of  1500
# File: ./digit_dataset/train/9_nicolas_16.wav   1409  of  1500
# File: ./digit_dataset/train/9_nicolas_17.wav   1410  of  1500
# File: ./digit_dataset/train/9_nicolas_18.wav   1411  of  1500
# File: ./digit_dataset/train/9_nicolas_19.wav   1412  of  1500
# File: ./digit_dataset/train/9_nicolas_2.wav   1413  of  1500
# File: ./digit_dataset/train/9_nicolas_20.wav   1414  of  1500
# File: ./digit_dataset/train/9_nicolas_21.wav   1415  of  1500
# File: ./digit_dataset/train/9_nicolas_22.wav   1416  of  1500
# File: ./digit_dataset/train/9_nicolas_23.wav   1417  of  1500
# File: ./digit_dataset/train/9_nicolas_24.wav   1418  of  1500
# File: ./digit_dataset/train/9_nicolas_25.wav   1419  of  1500
# File: ./digit_dataset/train/9_nicolas_26.wav   1420  of  1500
# File: ./digit_dataset/train/9_nicolas_27.wav   1421  of  1500
# File: ./digit_dataset/train/9_nicolas_28.wav   1422  of  1500
# File: ./digit_dataset/train/9_nicolas_29.wav   1423  of  1500
# File: ./digit_dataset/train/9_nicolas_3.wav   1424  of  1500
# File: ./digit_dataset/train/9_nicolas_30.wav   1425  of  1500
# File: ./digit_dataset/train/9_nicolas_31.wav   1426  of  1500
# File: ./digit_dataset/train/9_nicolas_32.wav   1427  of  1500
# File: ./digit_dataset/train/9_nicolas_33.wav   1428  of  1500
# File: ./digit_dataset/train/9_nicolas_34.wav   1429  of  1500
# File: ./digit_dataset/train/9_nicolas_35.wav   1430  of  1500
# File: ./digit_dataset/train/9_nicolas_36.wav   1431  of  1500
# File: ./digit_dataset/train/9_nicolas_37.wav   1432  of  1500
# File: ./digit_dataset/train/9_nicolas_38.wav   1433  of  1500
# File: ./digit_dataset/train/9_nicolas_39.wav   1434  of  1500
# File: ./digit_dataset/train/9_nicolas_4.wav   1435  of  1500
# File: ./digit_dataset/train/9_nicolas_40.wav   1436  of  1500
# File: ./digit_dataset/train/9_nicolas_41.wav   1437  of  1500
# File: ./digit_dataset/train/9_nicolas_42.wav   1438  of  1500
# File: ./digit_dataset/train/9_nicolas_43.wav   1439  of  1500
# File: ./digit_dataset/train/9_nicolas_44.wav   1440  of  1500
# File: ./digit_dataset/train/9_nicolas_45.wav   1441  of  1500
# File: ./digit_dataset/train/9_nicolas_46.wav   1442  of  1500
# File: ./digit_dataset/train/9_nicolas_47.wav   1443  of  1500
# File: ./digit_dataset/train/9_nicolas_48.wav   1444  of  1500
# File: ./digit_dataset/train/9_nicolas_49.wav   1445  of  1500
# File: ./digit_dataset/train/9_nicolas_5.wav   1446  of  1500
# File: ./digit_dataset/train/9_nicolas_6.wav   1447  of  1500
# File: ./digit_dataset/train/9_nicolas_7.wav   1448  of  1500
# File: ./digit_dataset/train/9_nicolas_8.wav   1449  of  1500
# File: ./digit_dataset/train/9_nicolas_9.wav   1450  of  1500
# File: ./digit_dataset/train/9_theo_0.wav   1451  of  1500
# File: ./digit_dataset/train/9_theo_1.wav   1452  of  1500
# File: ./digit_dataset/train/9_theo_10.wav   1453  of  1500
# File: ./digit_dataset/train/9_theo_11.wav   1454  of  1500
# File: ./digit_dataset/train/9_theo_12.wav   1455  of  1500
# File: ./digit_dataset/train/9_theo_13.wav   1456  of  1500
# File: ./digit_dataset/train/9_theo_14.wav   1457  of  1500
# File: ./digit_dataset/train/9_theo_15.wav   1458  of  1500
# File: ./digit_dataset/train/9_theo_16.wav   1459  of  1500
# File: ./digit_dataset/train/9_theo_17.wav   1460  of  1500
# File: ./digit_dataset/train/9_theo_18.wav   1461  of  1500
# File: ./digit_dataset/train/9_theo_19.wav   1462  of  1500
# File: ./digit_dataset/train/9_theo_2.wav   1463  of  1500
# File: ./digit_dataset/train/9_theo_20.wav   1464  of  1500
# File: ./digit_dataset/train/9_theo_21.wav   1465  of  1500
# File: ./digit_dataset/train/9_theo_22.wav   1466  of  1500
# File: ./digit_dataset/train/9_theo_23.wav   1467  of  1500
# File: ./digit_dataset/train/9_theo_24.wav   1468  of  1500
# File: ./digit_dataset/train/9_theo_25.wav   1469  of  1500
# File: ./digit_dataset/train/9_theo_26.wav   1470  of  1500
# File: ./digit_dataset/train/9_theo_27.wav   1471  of  1500
# File: ./digit_dataset/train/9_theo_28.wav   1472  of  1500
# File: ./digit_dataset/train/9_theo_29.wav   1473  of  1500
# File: ./digit_dataset/train/9_theo_3.wav   1474  of  1500
# File: ./digit_dataset/train/9_theo_30.wav   1475  of  1500
# File: ./digit_dataset/train/9_theo_31.wav   1476  of  1500
# File: ./digit_dataset/train/9_theo_32.wav   1477  of  1500
# File: ./digit_dataset/train/9_theo_33.wav   1478  of  1500
# File: ./digit_dataset/train/9_theo_34.wav   1479  of  1500
# File: ./digit_dataset/train/9_theo_35.wav   1480  of  1500
# File: ./digit_dataset/train/9_theo_36.wav   1481  of  1500
# File: ./digit_dataset/train/9_theo_37.wav   1482  of  1500
# File: ./digit_dataset/train/9_theo_38.wav   1483  of  1500
# File: ./digit_dataset/train/9_theo_39.wav   1484  of  1500
# File: ./digit_dataset/train/9_theo_4.wav   1485  of  1500
# File: ./digit_dataset/train/9_theo_40.wav   1486  of  1500
# File: ./digit_dataset/train/9_theo_41.wav   1487  of  1500
# File: ./digit_dataset/train/9_theo_42.wav   1488  of  1500
# File: ./digit_dataset/train/9_theo_43.wav   1489  of  1500
# File: ./digit_dataset/train/9_theo_44.wav   1490  of  1500
# File: ./digit_dataset/train/9_theo_45.wav   1491  of  1500
# File: ./digit_dataset/train/9_theo_46.wav   1492  of  1500
# File: ./digit_dataset/train/9_theo_47.wav   1493  of  1500
# File: ./digit_dataset/train/9_theo_48.wav   1494  of  1500
# File: ./digit_dataset/train/9_theo_49.wav   1495  of  1500
# File: ./digit_dataset/train/9_theo_5.wav   1496  of  1500
# File: ./digit_dataset/train/9_theo_6.wav   1497  of  1500
# File: ./digit_dataset/train/9_theo_7.wav   1498  of  1500
# File: ./digit_dataset/train/9_theo_8.wav   1499  of  1500
# File: ./digit_dataset/train/9_theo_9.wav   1500  of  1500
# All dataset features have been extracted.
# D:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
train_X = datagen.train_X
train_Y = datagen.train_Y

train_X, valid_X, train_Y, valid_Y = train_test_split(train_X, train_Y, test_size = 0.2)

# %%
model = Sequential()
model.add(LSTM(units=128, dropout=0.01, recurrent_dropout=0.35, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(units=32, dropout=0.01, recurrent_dropout=0.35, return_sequences=False))
model.add(Dense(units= 256, activation='relu'))
model.add(Dense(units= 128, activation='relu'))
model.add(Dense(units= 64, activation='relu'))
model.add(Dense(units= 10, activation='softmax'))

# %%
model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
model.fit(
        train_X,
        train_Y,
        epochs = 20,
        steps_per_epoch = 26922 // 16
)
# Out:
# Epoch 1/20
# 1682/1682 [==============================] - 328s 195ms/step - loss: 0.0822 - acc: 0.9723s - loss: 0.0822 - acc: 0.97
# Epoch 2/20
#  815/1682 [=============>................] - ETA: 2:56 - loss: 0.0125 - acc: 0.9958
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-e344f0fb4ea8> in <module>()
#       3         train_Y,
#       4         epochs = 20,
# ----> 5         steps_per_epoch = 26922 // 16
#       6 )
#
# D:\Anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     961                               initial_epoch=initial_epoch,
#     962                               steps_per_epoch=steps_per_epoch,
# --> 963                               validation_steps=validation_steps)
#     964
#     965     def evaluate(self, x=None, y=None,
#
# D:\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1710                               initial_epoch=initial_epoch,
#    1711                               steps_per_epoch=steps_per_epoch,
# -> 1712                               validation_steps=validation_steps)
#    1713
#    1714     def evaluate(self, x=None, y=None,
#
# D:\Anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1186                     batch_logs['size'] = 1
#    1187                     callbacks.on_batch_begin(step_index, batch_logs)
# -> 1188                     outs = f(ins)
#    1189
#    1190                     if not isinstance(outs, list):
#
# D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
model.save("digits_spoken.h5")
print("Model saved&ready")
# Out:
# Model saved&ready

# %%
test_file_path = "./digit_dataset/test/3_lukasz.wav"
test_X = AudioDataGenerator().preprocessSingleFile(test_file_path)
test_X
# Out:
# array([[[-4.47053150e+02,  1.90021621e+02, -2.73052835e+01,
#          -5.37567322e+00,  3.07618111e+00,  2.71011216e+01,
#          -2.39545980e+00, -2.58920524e+00, -1.42352031e+01,
#          -2.22032945e+01, -2.17246606e+01, -3.97334638e+01,
#          -3.69143796e+00,  8.02314951e+02,  1.73705659e-01,
#           8.87109898e-02,  2.48424438e-01,  5.53451784e-01,
#           4.36127649e-01,  1.00000000e+00,  5.46225540e-01,
#           2.13360538e-01,  1.00092874e-01,  5.72113169e-02,
#           4.75720589e-02,  9.88044305e-02,  3.55600077e+01,
#           3.12887067e+01,  2.40110754e+01,  2.47616459e+01,
#           3.79179969e+01,  2.25720360e+01,  1.93892781e+01],
#         [-4.27316841e+02,  2.14075246e+02, -2.28026925e+01,
#          -1.52494769e+01, -6.15745352e+00,  2.54344092e+01,
#          -3.93632670e+00, -8.90940235e+00, -1.06663081e+01,
#          -2.28204892e+01, -2.86568235e+01, -4.72200504e+01,
#          -9.18515229e+00,  6.66589097e+02,  2.90391766e-01,
#           3.99425957e-02,  9.83560419e-02,  3.88287849e-01,
#           1.00000000e+00,  8.29864085e-01,  2.78767279e-01,
#           7.73659993e-02,  6.11539144e-02,  3.13013656e-02,
#           7.20211158e-02,  4.30041364e-01,  3.30245026e+01,
#           1.96685649e+01,  2.39381865e+01,  2.31346460e+01,
#           2.60173554e+01,  1.34969450e+01,  2.07285821e+01],
#         [-4.09084974e+02,  2.29859961e+02, -3.31818070e+01,
#          -3.47009086e+01, -6.00131253e+00,  3.72438916e+01,
#          -1.79978197e+00, -1.45717763e+01, -5.82657265e+00,
#          -1.80481145e+01, -3.38652337e+01, -4.71463862e+01,
#          -7.30090265e+00,  7.27692458e+02,  2.38116740e-01,
#           6.41386943e-02,  1.37298363e-01,  4.38016556e-01,
#           1.00000000e+00,  3.76745919e-01,  5.62868872e-02,
#           4.21660080e-02,  7.06506087e-02,  3.34366495e-02,
#           2.19981584e-01,  7.18382214e-01,  3.41323464e+01,
#           1.92470980e+01,  3.29460693e+01,  2.27367538e+01,
#           2.77633332e+01,  1.33650486e+01,  3.95795644e+01],
#         [-3.84816502e+02,  2.38416441e+02, -5.83517327e+01,
#          -5.02654510e+01,  8.20246120e+00,  5.24528763e+01,
#          -4.02153839e+00, -2.31462990e+01, -1.32486404e+01,
#          -1.83768222e+01, -2.85201519e+01, -3.96758010e+01,
#          -4.61886931e+00,  8.80057876e+02,  1.17350753e-01,
#           1.83681615e-01,  3.49792547e-01,  8.70729354e-01,
#           1.00000000e+00,  2.16622773e-01,  5.91630229e-02,
#           1.60016127e-01,  7.02791783e-02,  1.18793090e-01,
#           9.58588486e-01,  8.85726191e-01,  3.80338605e+01,
#           2.06053888e+01,  2.82980266e+01,  2.06583390e+01,
#           3.29391290e+01,  1.41115650e+01,  4.03789544e+01],
#         [-3.67769470e+02,  2.33179948e+02, -8.76332313e+01,
#          -3.96580222e+01,  3.48432631e+01,  4.36976075e+01,
#          -1.91112856e+01, -2.98561955e+01, -2.32154434e+01,
#          -1.84995124e+01, -1.48624982e+01, -3.55650056e+01,
#          -9.42945590e+00,  1.07667415e+03,  3.22073662e-02,
#           6.44253104e-02,  1.91025399e-01,  5.16373997e-01,
#           3.16317041e-01,  5.40670496e-02,  2.03503670e-01,
#           5.94254680e-01,  2.17558381e-01,  3.61816854e-01,
#           1.00000000e+00,  3.76732656e-01,  4.29378661e+01,
#           1.78983204e+01,  3.02015069e+01,  2.21830873e+01,
#           3.58629295e+01,  1.60785605e+01,  3.94065170e+01],
#         [-3.65013882e+02,  2.16519404e+02, -1.06099415e+02,
#          -1.02572617e+01,  5.94724193e+01,  2.13921360e+01,
#          -3.74741303e+01, -3.16508868e+01, -2.42798359e+01,
#          -1.44363315e+01, -8.11938201e+00, -3.71995172e+01,
#          -1.20172167e+01,  1.23989580e+03,  4.25004325e-02,
#           7.63615785e-02,  1.77440284e-01,  1.33879456e-01,
#           4.78580493e-02,  1.67259270e-02,  2.09137677e-01,
#           5.71148691e-01,  6.93510468e-01,  1.00000000e+00,
#           6.32641802e-01,  2.49112052e-01,  3.03386999e+01,
#           1.97917963e+01,  2.75823001e+01,  2.25067550e+01,
#           3.23209273e+01,  1.67285963e+01,  3.96443671e+01]]])

# %%
predictions = model.predict(test_X)

# %%
predictions
# Out:
# array([[1.5539719e-03, 1.6671412e-07, 2.5102361e-05, 9.5862466e-01,
#         1.2686050e-07, 3.4277420e-02, 3.0887662e-10, 4.8169372e-06,
#         2.2578424e-10, 5.5138553e-03]], dtype=float32)
